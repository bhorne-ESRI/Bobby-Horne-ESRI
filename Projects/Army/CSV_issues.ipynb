# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\bob10704\Downloads\Army_Geospatial_Directory.xlsx", sheet_name=0)
geo_list = list(df['Unit City'])
geo_list.sort()
geo_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-7aed0ff0e256> in <module>
#       1 df = pd.read_excel(r"C:\Users\bob10704\Downloads\Army_Geospatial_Directory.xlsx", sheet_name=0)
#       2 geo_list = list(df['Unit City'])
# ----> 3 geo_list.sort()
#       4 geo_list
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
df = pd.read_excel(r"C:\Users\bob10704\Desktop\Projects\1.Active Projects\Engineers\Geospatial Engineer Roster\cities.xlsx", sheet_name=0)
city_list = list(df['NAME'])
city_list.sort()
city_list
# Out:
# ['Aaronsburg',
#  'Aaronsburg',
#  'Abanda',
#  'Abbeville',
#  'Abbeville',
#  'Abbeville',
#  'Abbeville',
#  'Abbeville',
#  'Abbotsford',
#  'Abbott',
#  'Abbottstown',
#  'Abbs Valley',
#  'Abbyville',
#  'Abercrombie',
#  'Aberdeen',
#  'Aberdeen',
#  'Aberdeen',
#  'Aberdeen',
#  'Aberdeen',
#  'Aberdeen',
#  'Aberdeen',
#  'Aberdeen',
#  'Aberdeen Gardens',
#  'Aberdeen Proving Ground',
#  'Abernathy',
#  'Abeytas',
#  'Abie',
#  'Abilene',
#  'Abilene',
#  'Abingdon',
#  'Abingdon',
#  'Abingdon',
#  'Abington',
#  'Abiquiu',
#  'Abita Springs',
#  'Abney Crossroads',
#  'Abram',
#  'Abrams',
#  'Absarokee',
#  'Absecon',
#  'Absecon Highlands',
#  'Acacia Villas',
#  'Acala',
#  'Acalanes Ridge',
#  'Acampo',
#  'Accident',
#  'Accokeek',
#  'Accomac',
#  'Accord',
#  'Accoville',
#  'Acequia',
#  'Achille',
#  'Ackerly',
#  'Ackerman',
#  'Ackermanville',
#  'Ackley',
#  'Ackworth',
#  'Acme',
#  'Acomita Lake',
#  'Acorn',
#  'Acres Green',
#  'Acton',
#  'Acton',
# ...

# %%
missing_city = [set(geo_list) - set(city_list)]
missing_city
# Out:
# [{'Camp Casey',
#   'Camp Humphreys',
#   'Clackamas',
#   'Cp Ripley',
#   'Dal Molin',
#   'Del Valle Afrc',
#   'East Camp Graffen',
#   'Eglin Afb Destin',
#   'Fort Benning',
#   'Fort Campbell',
#   'Fort Gordon',
#   'Fort Jackson',
#   'Fort Leavenworth',
#   'Fort Polk',
#   'Fort Sam Houston',
#   'Fort Shafter',
#   'Fort Sill',
#   'Fort Snelling',
#   'Fort Wainwright',
#   'Gunpowder',
#   'Honolulu',
#   'Humphries En Ctr',
#   'Hunter Aaf',
#   'Indianapolis',
#   'Invergrove',
#   'Islamabad',
#   'Jb Elmendorf-Rich',
#   'Jb Lewis-Mcchord',
#   'Jb Mcguire-Dix',
#   'Jblm Lewis',
#   'Jbph-H Hickam Fld',
#   'Macdill Afb',
#   'Mainz Kastel',
#   'Managua',
#   'Mcleansville',
#   'Molesworth',
#   'Natick',
#   'Panzer Kaserne Rp',
#   'Peterson Sfb',
#   'Rc Havelock',
#   'Red House',
#   'Rock Island Ars',
#   'S Camp Vilseck',
#   'Saint Louis',
#   'Schofield Brks',
#   'Sembach',
#   'Seoul',
#   'Shaw Afb',
#   'Smith Barracks',
#   'St Augustine',
# ...
