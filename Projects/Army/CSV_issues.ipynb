# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:/Users/bob10704/Desktop/Army Engineer Leader Directory -  FY23 Q1 - Final v1.xlsx", sheet_name=1)
geo_list = list(df['Unit City Proper'])
geo_list.sort()
geo_list
# Out:
# ['Aberdeen Proving Ground',
#  'Altoona',
#  'Anderson',
#  'Annapolis',
#  'Annapolis',
#  'Annapolis',
#  'Annapolis',
#  'Annapolis',
#  'Annapolis',
#  'Annville',
#  'Annville',
#  'Arden Hills',
#  'Arden Hills',
#  'Arden Hills',
#  'Arden Hills',
#  'Arden Hills',
#  'Auburn',
#  'Aurora',
#  'Austin',
#  'Austin',
#  'Austin',
#  'Austin',
#  'Austin',
#  'Austin',
#  'Barboursville',
#  'Belton',
#  'Birmingham',
#  'Bloomington',
#  'Bluffdale',
#  'Bluffdale',
#  'Bluffdale',
#  'Bluffdale',
#  'Bluffdale',
#  'Bluffdale',
#  'Bluffdale',
#  'Bluffdale',
#  'Bluffdale',
#  'Boise City',
#  'Boise City',
#  'Boise City',
#  'Boone',
#  'Boone',
#  'Bowling Green',
#  'Buckeye',
#  'Camp Casey',
#  'Camp Douglas',
#  'Camp Douglas',
#  'Camp Humphreys',
#  'Camp Humphreys',
#  'Camp Humphreys',
#  'Camp Humphreys',
#  'Camp Humphreys',
#  'Camp Humphreys',
#  'Camp Humphreys',
#  'Camp Humphreys',
#  'Camp Humphreys',
#  'Camp Humphreys',
#  'Charleston',
#  'Charleston',
#  'Charlotte',
#  'Chattanooga',
#  'Chattanooga',
#  'Cheyenne',
#  'Cheyenne',
#  'Chicago',
#  'Cincinnati',
#  'Clackamas',
#  'Clinton',
#  'Clinton',
#  'Clinton',
#  'Colorado Springs',
#  'Colorado Springs',
#  'Colorado Springs',
#  'Colorado Springs',
#  'Colorado Springs',
#  'Colorado Springs',
#  'Colorado Springs',
#  'Colorado Springs',
#  'Colorado Springs',
#  'Colorado Springs',
#  'Colorado Springs',
#  'Colorado Springs',
#  'Colorado Springs',
#  'Colorado Springs',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Cp Ripley',
#  'Dal Molin',
#  'Dal Molin',
#  'Darien',
#  'Del Valle Afrc',
#  'Denver',
#  'East Camp Graffen',
#  'East Camp Graffen',
#  'East Camp Graffen',
#  'East Camp Graffen',
#  'Eau Claire',
#  'Edinburgh',
#  'Eglin Afb Destin',
#  'Eglin Afb Destin',
#  'Eglin Afb Destin',
#  'Fairfax',
#  'Fallbrook',
#  'Fargo',
#  'Fayetteville',
#  'Fayetteville',
#  'Forest City',
#  'Fort Belvoir',
#  'Fort Belvoir',
#  'Fort Belvoir',
#  'Fort Belvoir',
#  'Fort Benning',
#  'Fort Benning',
#  'Fort Benning',
#  'Fort Benning',
#  'Fort Benning',
#  'Fort Benning',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bliss',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Bragg',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Campbell',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Carson',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Drum',
#  'Fort Gordon',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Hood',
#  'Fort Jackson',
#  'Fort Jackson',
#  'Fort Jackson',
#  'Fort Jackson',
#  'Fort Jackson',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Knox',
#  'Fort Leavenworth',
#  'Fort Leavenworth',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Leonard Wood',
#  'Fort Meade',
#  'Fort Meade',
#  'Fort Meade',
#  'Fort Polk',
#  'Fort Polk',
#  'Fort Polk',
#  'Fort Polk',
#  'Fort Polk',
#  'Fort Polk',
#  'Fort Riley',
#  'Fort Riley',
#  'Fort Riley',
#  'Fort Riley',
#  'Fort Riley',
#  'Fort Riley',
#  'Fort Riley',
#  'Fort Riley',
#  'Fort Riley',
#  'Fort Riley',
#  'Fort Riley',
#  'Fort Riley',
#  'Fort Riley',
#  'Fort Riley',
#  'Fort Riley',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Sam Houston',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Shafter',
#  'Fort Sill',
#  'Fort Sill',
#  'Fort Sill',
#  'Fort Snelling',
#  'Fort Snelling',
#  'Fort Snelling',
#  'Fort Snelling',
#  'Fort Snelling',
#  'Fort Stewart',
#  'Fort Stewart',
#  'Fort Stewart',
#  'Fort Stewart',
#  'Fort Stewart',
#  'Fort Stewart',
#  'Fort Stewart',
#  'Fort Stewart',
#  'Fort Stewart',
#  'Fort Stewart',
#  'Fort Stewart',
#  'Fort Stewart',
#  'Fort Stewart',
#  'Fort Stewart',
#  'Fort Wainwright',
#  'Fort Wainwright',
#  'Fort Wainwright',
#  'Frankfort',
#  'Franklin',
#  'Franklin',
#  'Franklin',
#  'Glenville',
#  'Glenville',
#  'Glenville',
#  'Gloucester',
#  'Gloucester',
#  'Grand Prairie',
#  'Grand Prairie',
#  'Grand Prairie',
#  'Green Bay',
#  'Greensboro',
#  'Greensboro',
#  'Gunpowder',
#  'Gunpowder',
#  'Harrisburg',
#  'Harrisburg',
#  'Homewood',
#  'Honolulu',
#  'Honolulu',
#  'Horsham',
#  'Horsham',
#  'Houston',
#  'Houston',
#  'Hudson',
#  'Humphries En Ctr',
#  'Humphries En Ctr',
#  'Humphries En Ctr',
#  'Humphries En Ctr',
#  'Humphries En Ctr',
#  'Humphries En Ctr',
#  'Hunter Aaf',
#  'Hunter Aaf',
#  'Hunter Aaf',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Invergrove',
#  'Islamabad',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jb Elmendorf-Rich',
#  'Jb Lewis-Mcchord',
#  'Jb Lewis-Mcchord',
#  'Jb Lewis-Mcchord',
#  'Jb Mcguire-Dix',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jblm Lewis',
#  'Jbph-H Hickam Fld',
#  'Jefferson City',
#  'Jericho',
#  'Jericho',
#  'Kansas City',
#  'Kansas City',
#  'Kapolei',
#  'Kapolei',
#  'Knoxville',
#  'Knoxville',
#  'Knoxville',
#  'Kokomo',
#  'Kokomo',
#  'Lafayette',
#  'Lafayette',
#  'Lafayette',
#  'Lakewood',
#  'Las Vegas',
#  'Latham',
#  'Lexington',
#  'Lexington',
#  'Lincoln',
#  'Lincoln',
#  'Lincoln',
#  'Long Beach',
#  'Los Alamitos',
#  'Los Alamitos',
#  'Louisville',
#  'Macdill Afb',
#  'Macdill Afb',
#  'Macdill Afb',
#  'Macdill Afb',
#  'Macdill Afb',
#  'Macdill Afb',
#  'Macdill Afb',
#  'Macdill Afb',
#  'Macdill Afb',
#  'Mainz Kastel',
#  'Mainz Kastel',
#  'Mainz Kastel',
#  'Mainz Kastel',
#  'Managua',
#  'Manchester',
#  'Manchester',
#  'Manhattan',
#  'Mcleansville',
#  'Miami',
#  'Miami',
#  'Miami',
#  'Miami',
#  'Milan',
#  'Milwaukee',
#  'Mobile',
#  'Molesworth',
#  'Molesworth',
#  'Molesworth',
#  'Molesworth',
#  'Molesworth',
#  'Molesworth',
#  'Molesworth',
#  'Molesworth',
#  'Molesworth',
#  'Montgomery',
#  'Montgomery',
#  'Montgomery',
#  'Montgomery',
#  'Montgomery',
#  'Montgomery',
#  'Montgomery',
#  'Montgomery',
#  'Morrisville',
#  'Mountain View',
#  'Mustang',
#  'Naples',
#  'Natick',
#  'New York',
#  'Newberry',
#  'Newberry',
#  'Normal',
#  'Normal',
#  'North Little Rock',
#  'Orlando',
#  'Panzer Kaserne Rp',
#  'Panzer Kaserne Rp',
#  'Panzer Kaserne Rp',
#  'Panzer Kaserne Rp',
#  'Panzer Kaserne Rp',
#  'Peterson Sfb',
#  'Phoenix',
#  'Phoenix',
#  'Phoenix',
#  'Pinellas Park',
#  'Pinellas Park',
#  'Pineville',
#  'Pineville',
#  'Pineville',
#  'Pittsburgh',
#  'Pittsburgh',
#  'Pittsburgh',
#  'Portage',
#  'Rc Havelock',
#  'Red House',
#  'Red House',
#  'Redding',
#  'Rio Rancho',
#  'Riverside',
#  'Rock Island Ars',
#  'Rosemount',
#  'S Camp Vilseck',
#  'S Camp Vilseck',
#  'S Camp Vilseck',
#  'S Camp Vilseck',
#  'Saint Louis',
#  'Saint Louis',
#  'Saint Louis',
#  'Saint Louis',
#  'San Antonio',
#  'San Diego',
#  'San Francisco',
#  'Sanford',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Schofield Brks',
#  'Scranton',
#  'Seattle',
#  'Seattle',
#  'Seattle',
#  'Sedalia',
#  'Sembach',
#  'Sembach',
#  'Seoul',
#  'Seoul',
#  'Seoul',
#  'Shaw Afb',
#  'Shaw Afb',
#  'Shaw Afb',
#  'Shaw Afb',
#  'Shaw Afb',
#  'Shaw Afb',
#  'Shaw Afb',
#  'Shaw Afb',
#  'Shaw Afb',
#  'Shaw Afb',
#  'Shaw Afb',
#  'Shaw Afb',
#  'Shaw Afb',
#  'Shelbyville',
#  'Shelbyville',
#  'Sioux Falls',
#  'Sioux Falls',
#  'Smith Barracks',
#  'Smith Barracks',
#  'Smith Barracks',
#  'Springfield',
#  'Springfield',
#  'Springfield',
#  'Springfield',
#  'Springfield',
#  'Springfield',
#  'Springfield',
#  'Springfield',
#  'Springfield',
#  'Springfield',
#  'Springfield',
#  'St Augustine',
#  'St Louis',
#  'St Louis',
#  'St Louis',
#  'St Louis',
#  'St Louis',
#  'St Louis',
#  'Starke',
#  'Staunton',
#  'Staunton',
#  'Strafford',
#  'Syracuse',
#  'Syracuse',
#  'Towson',
#  'Trenton',
#  'Trenton',
#  'Troy',
#  'Tukwila',
#  'Tulsa',
#  'Tulsa',
#  'Tupelo',
#  'Urbana',
#  'Urbana',
#  'Vicenza',
#  'Vicenza',
#  'Vicenza',
#  'Vicenza',
#  'Vicenza',
#  'Vicenza',
#  'Vicenza',
#  'Vicenza',
#  'Vicenza',
#  'Vicenza',
#  'Vicenza',
#  'Vicenza',
#  'Vicenza',
#  'Vicenza',
#  'Vicenza',
#  'Vicenza',
#  'Vicenza',
#  'Vicksburg',
#  'Vicksburg',
#  'Vicksburg',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Wheeler Aaf',
#  'Wheeler Aaf',
#  'White House',
#  'White Plains',
#  'White Plains',
#  'Whitehall',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wiesbaden Clay Ks',
#  'Wyandotte',
#  'Ypsilanti']

# %%
df = pd.read_excel(r"C:\Users\bob10704\Desktop\Projects\1.Active Projects\Engineers\Geospatial Engineer Roster\cities.xlsx", sheet_name=0)
city_list = list(df['NAME'])
city_list.sort()
city_list
# Out:
# ['Aaronsburg',
#  'Aaronsburg',
#  'Abanda',
#  'Abbeville',
#  'Abbeville',
#  'Abbeville',
#  'Abbeville',
#  'Abbeville',
#  'Abbotsford',
#  'Abbott',
#  'Abbottstown',
#  'Abbs Valley',
#  'Abbyville',
#  'Abercrombie',
#  'Aberdeen',
#  'Aberdeen',
#  'Aberdeen',
#  'Aberdeen',
#  'Aberdeen',
#  'Aberdeen',
#  'Aberdeen',
#  'Aberdeen',
#  'Aberdeen Gardens',
#  'Aberdeen Proving Ground',
#  'Abernathy',
#  'Abeytas',
#  'Abie',
#  'Abilene',
#  'Abilene',
#  'Abingdon',
#  'Abingdon',
#  'Abingdon',
#  'Abington',
#  'Abiquiu',
#  'Abita Springs',
#  'Abney Crossroads',
#  'Abram',
#  'Abrams',
#  'Absarokee',
#  'Absecon',
#  'Absecon Highlands',
#  'Acacia Villas',
#  'Acala',
#  'Acalanes Ridge',
#  'Acampo',
#  'Accident',
#  'Accokeek',
#  'Accomac',
#  'Accord',
#  'Accoville',
#  'Acequia',
#  'Achille',
#  'Ackerly',
#  'Ackerman',
#  'Ackermanville',
#  'Ackley',
#  'Ackworth',
#  'Acme',
#  'Acomita Lake',
#  'Acorn',
#  'Acres Green',
#  'Acton',
#  'Acton',
#  'Acushnet Center',
#  'Acworth',
#  'Ada',
#  'Ada',
#  'Ada',
#  'Ada',
#  'Adair',
#  'Adair',
#  'Adair',
#  'Adair Village',
#  'Adairsville',
#  'Adairville',
#  'Adak',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams Center',
#  'Adams Run',
#  'Adamsburg',
#  'Adamson',
#  'Adamstown',
#  'Adamstown',
#  'Adamsville',
#  'Adamsville',
#  'Adamsville',
#  'Adamsville',
#  'Addieville',
#  'Addington',
#  'Addis',
#  'Addison',
#  'Addison',
#  'Addison',
#  'Addison',
#  'Addison',
#  'Addison',
#  'Addison (Webster Springs)',
#  'Addy',
#  'Addyston',
#  'Adel',
#  'Adel',
#  'Adelanto',
#  'Adeline',
#  'Adelino',
#  'Adell',
#  'Adelphi',
#  'Adelphi',
#  'Adena',
#  'Adin',
#  'Admire',
#  'Adona',
#  'Adrian',
#  'Adrian',
#  'Adrian',
#  'Adrian',
#  'Adrian',
#  'Adrian',
#  'Adrian',
#  'Advance',
#  'Advance',
#  'Advance',
#  'Advance',
#  'Adwolf',
#  'Aetna Estates',
#  'Affton',
#  'Afton',
#  'Afton',
#  'Afton',
#  'Afton',
#  'Afton',
#  'Afton',
#  'Agar',
#  'Agawam Town',
#  'Agency',
#  'Agency',
#  'Agency Village',
#  'Agenda',
#  'Ages',
#  'Agnew',
#  'Agoura Hills',
#  'Agra',
#  'Agra',
#  'Agricola',
#  'Agua Dulce',
#  'Agua Dulce',
#  'Agua Dulce',
#  'Agua Fria',
#  'Aguanga',
#  'Aguila',
#  'Aguilar',
#  'Aguilares',
#  'Ahmeek',
#  'Ahoskie',
#  'Ahtanum',
#  'Ahuimanu',
#  'Ahwahnee',
#  'Ai',
#  'Aiea',
#  'Aiken',
#  'Ailey',
#  'Ainaloa',
#  'Ainsworth',
#  'Ainsworth',
#  'Air Force Academy',
#  'Airmont',
#  'Airport',
#  'Airport Drive',
#  'Airport Heights',
#  'Airport Road Addition',
#  'Airway Heights',
#  'Aitkin',
#  'Ajo',
#  'Ak Chin',
#  'Ak-Chin Village',
#  'Akaska',
#  'Akeley',
#  'Akhiok',
#  'Akiachak',
#  'Akiak',
#  'Akins',
#  'Akron',
#  'Akron',
#  'Akron',
#  'Akron',
#  'Akron',
#  'Akron',
#  'Akron',
#  'Akron',
#  'Akutan',
#  'Akwesasne',
#  'Alabaster',
#  'Alachua',
#  'Alafaya',
#  'Alakanuk',
#  'Alamance',
#  'Alameda',
#  'Alamillo',
#  'Alamo',
#  'Alamo',
#  'Alamo',
#  'Alamo',
#  'Alamo',
#  'Alamo',
#  'Alamo',
#  'Alamo',
#  'Alamo Beach',
#  'Alamo Heights',
#  'Alamo Lake',
#  'Alamogordo',
#  'Alamosa',
#  'Alamosa East',
#  'Alanreed',
#  'Alanson',
#  'Alapaha',
#  'Alatna',
#  'Alba',
#  'Alba',
#  'Alba',
#  'Alba',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albee',
#  'Albemarle',
#  'Albers',
#  'Albert',
#  'Albert City',
#  'Albert Lea',
#  'Alberta',
#  'Alberta',
#  'Alberton',
#  'Albertson',
#  'Albertville',
#  'Albertville',
#  'Albia',
#  'Albin',
#  'Albion',
#  'Albion',
#  'Albion',
#  'Albion',
#  'Albion',
#  'Albion',
#  'Albion',
#  'Albion',
#  'Albion',
#  'Albion',
#  'Albion',
#  'Albright',
#  'Albrightsville',
#  'Albuquerque',
#  'Alburgh',
#  'Alburnett',
#  'Alburtis',
#  'Alcalde',
#  'Alcan Border',
#  'Alcester',
#  'Alcoa',
#  'Alcolu',
#  'Alcorn State University',
#  'Alcova',
#  'Alda',
#  'Aldan',
#  'Alden',
#  'Alden',
#  'Alden',
#  'Alden',
#  'Alden',
#  'Alden',
#  'Alder',
#  'Alder',
#  'Alderpoint',
#  'Alderson',
#  'Alderson',
#  'Alderton',
#  'Alderwood Manor',
#  'Aldie',
#  'Aldine',
#  'Aldora',
#  'Aldrich',
#  'Aldrich',
#  'Aledo',
#  'Aledo',
#  'Aleknagik',
#  'Aleneva',
#  'Alex',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander City',
#  'Alexandria',
#  'Alexandria',
#  'Alexandria',
#  'Alexandria',
#  'Alexandria',
#  'Alexandria',
#  'Alexandria',
#  'Alexandria',
#  'Alexandria',
#  'Alexandria',
#  'Alexandria',
#  'Alexandria',
#  'Alexandria Bay',
#  'Alexis',
#  'Alexis',
#  'Alfarata',
#  'Alford',
#  'Alfordsville',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alger',
#  'Alger',
#  'Algiers',
#  'Algodones',
#  'Algoma',
#  'Algoma',
#  'Algona',
#  'Algona',
#  'Algonac',
#  'Algonquin',
#  'Algonquin',
#  'Algood',
#  'Alhambra',
#  'Alhambra',
#  'Alhambra Valley',
#  'Ali Chuk',
#  'Ali Chukson',
#  'Ali Molina',
#  'Alice',
#  'Alice',
#  'Alice Acres',
#  'Aliceville',
#  'Alicia',
#  'Aline',
#  'Aliquippa',
#  'Aliso Viejo',
#  'Alix',
#  'Allakaket',
#  'Allamuchy',
#  'Allardt',
#  'Alleene',
#  'Allegan',
#  'Allegany',
#  'Alleghany',
#  'Alleghenyville',
#  'Alleman',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen Park',
#  'Allendale',
#  'Allendale',
#  'Allendale',
#  'Allendale',
#  'Allendale',
#  'Allendale',
#  'Allenhurst',
#  'Allenhurst',
#  'Allenport',
#  'Allenport',
#  'Allens Grove',
#  'Allenspark',
#  'Allensville',
#  'Allensville',
#  'Allensworth',
#  'Allenton',
#  'Allentown',
#  'Allentown',
#  'Allentown',
#  'Allentown',
#  'Allenville',
#  'Allenville',
#  'Allenwood',
#  'Allenwood',
#  'Allerton',
#  'Allerton',
#  'Allgood',
#  'Alliance',
#  'Alliance',
#  'Alliance',
#  'Alligator',
#  'Allison',
#  'Allison',
#  'Allison',
#  'Allison Gap',
#  'Allison Park',
#  'Allisonia',
#  'Allouez',
#  'Alloway',
#  'Allport',
#  'Allport',
#  'Allyn',
#  'Alma',
#  'Alma',
#  'Alma',
#  'Alma',
#  'Alma',
#  'Alma',
#  'Alma',
#  'Alma',
#  'Alma',
#  'Alma',
#  'Alma',
#  'Alma Center',
#  'Almanor',
#  'Almedia',
#  'Almena',
#  'Almena',
#  'Almira',
#  'Almond',
#  'Almond',
#  'Almont',
#  'Almont',
#  'Almyra',
#  'Aloha',
#  'Alondra Park',
#  'Alorton',
#  'Alpaugh',
#  'Alpena',
#  'Alpena',
#  'Alpena',
#  'Alpha',
#  'Alpha',
#  'Alpha',
#  'Alpha',
#  'Alpharetta',
#  'Alpine',
#  'Alpine',
#  'Alpine',
#  'Alpine',
#  'Alpine',
#  'Alpine',
#  'Alpine',
#  'Alpine',
#  'Alpine',
#  'Alpine Northeast',
#  'Alpine Northwest',
#  'Alpine Village',
#  'Alsace Manor',
#  'Alsea',
#  'Alsen',
#  'Alsey',
#  'Alsip',
#  'Alston',
#  'Alta',
#  'Alta',
#  'Alta',
#  'Alta',
#  'Alta Sierra',
#  'Alta Sierra',
#  'Alta Vista',
#  'Alta Vista',
#  'Altadena',
#  'Altamahaw',
#  'Altamont',
#  'Altamont',
#  'Altamont',
#  'Altamont',
#  'Altamont',
#  'Altamont',
#  'Altamont',
#  'Altamont',
#  'Altamont',
#  'Altamonte Springs',
#  'Altavista',
#  'Altenburg',
#  'Altha',
#  'Altheimer',
#  'Altmar',
#  'Alto',
#  'Alto',
#  'Alto',
#  'Alto',
#  'Alto Bonito Heights',
#  'Alto Pass',
#  'Alton',
#  'Alton',
#  'Alton',
#  'Alton',
#  'Alton',
#  'Alton',
#  'Alton',
#  'Alton',
#  'Altona',
#  'Altona',
#  'Altona',
#  'Altona',
#  'Altoona',
#  'Altoona',
#  'Altoona',
#  'Altoona',
#  'Altoona',
#  'Altoona',
#  'Altoona',
#  'Altura',
#  'Alturas',
#  'Alturas',
#  'Altus',
#  'Altus',
#  'Alum Creek',
#  'Alum Rock',
#  'Alva',
#  'Alva',
#  'Alvan',
#  'Alvarado',
#  'Alvarado',
#  'Alverda',
#  'Alvin',
#  'Alvo',
#  'Alvord',
#  'Alvord',
#  'Alvordton',
#  'Alzada',
#  'Ama',
#  'Amada Acres',
#  'Amado',
#  'Amador City',
#  'Amador Pines',
#  'Amagansett',
#  'Amagon',
#  'Amalga',
#  'Amana',
#  'Amanda',
#  'Amanda Park',
#  'Amargosa',
#  'Amargosa Valley',
#  'Amarillo',
#  'Amasa',
#  'Amaya',
#  'Amazonia',
#  'Amber',
#  'Amberg',
#  'Amberley',
#  'Ambia',
#  'Ambler',
#  'Ambler',
#  'Amboy',
#  'Amboy',
#  'Amboy',
#  'Amboy',
#  'Ambridge',
#  'Ambrose',
#  'Ambrose',
#  'Amelia',
#  'Amelia',
#  'Amelia Court House',
#  'Amenia',
#  'Amenia',
#  'American Canyon',
#  'American Falls',
#  'American Fork',
#  'Americus',
#  'Americus',
#  'Americus',
#  'Amery',
#  'Ames',
#  'Ames',
#  'Ames',
#  'Ames',
#  'Ames',
#  'Ames',
#  'Ames Lake',
#  'Amesbury Town',
#  'Amesti',
#  'Amesville',
#  'Amherst',
#  'Amherst',
#  'Amherst',
#  'Amherst',
#  'Amherst',
#  'Amherst',
#  'Amherst',
#  'Amherst Junction',
#  'Amherst Town',
#  'Amherstdale',
#  'Amidon',
#  'Amistad',
#  'Amite City',
#  'Amity',
#  'Amity',
#  'Amity',
#  'Amity Gardens',
#  'Amityville',
#  'Ammon',
#  'Amo',
#  'Amonate',
#  'Amoret',
#  'Amorita',
#  'Amory',
#  'Ampere North',
#  'Amsterdam',
#  'Amsterdam',
#  'Amsterdam',
#  'Amsterdam',
#  'Anacoco',
#  'Anaconda-Deer Lodge County',
#  'Anacortes',
#  'Anacua',
#  'Anadarko',
#  'Anaheim',
#  'Anahola',
#  'Anahuac',
#  'Anaktuvuk Pass',
#  'Anamoose',
#  'Anamosa',
#  'Anatone',
#  'Anawalt',
#  'Anchor',
#  'Anchor Bay',
#  'Anchor Point',
#  'Anchorage',
#  'Anchorage',
#  'Ancient Oaks',
#  'Andale',
#  'Andalusia',
#  'Andalusia',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson Creek',
#  'Anderson Island',
#  'Andersonville',
#  'Andersonville',
#  'Andersonville',
#  'Andes',
#  'Andover',
#  'Andover',
#  'Andover',
#  'Andover',
#  'Andover',
#  'Andover',
#  'Andover',
#  'Andover',
#  'Andover',
#  'Andres',
#  'Andrew',
#  'Andrews',
#  'Andrews',
#  'Andrews',
#  'Andrews',
#  'Andrews',
#  'Andrews AFB',
#  'Anegam',
#  'Aneta',
#  'Aneth',
#  'Angel Fire',
#  'Angelica',
#  'Angelica',
#  'Angels',
#  'Angie',
#  'Angier',
#  'Angle Inlet',
#  'Angleton',
#  'Angola',
#  'Angola',
#  'Angola on the Lake',
#  'Angoon',
#  'Angostura',
#  'Anguilla',
#  'Angus',
#  'Angustura',
#  'Angwin',
#  'Aniak',
#  'Animas',
#  'Anita',
#  'Aniwa',
#  'Ankeny',
#  'Anmoore',
#  'Ann Arbor',
#  'Anna',
#  'Anna',
#  'Anna',
#  'Anna Maria',
#  'Annabella',
#  'Annada',
#  'Annandale',
#  'Annandale',
#  'Annandale',
#  'Annapolis',
#  'Annapolis',
#  'Annapolis',
#  'Annapolis Neck',
#  'Annawan',
#  'Annetta',
#  'Annetta North',
#  'Annetta South',
#  'Annex',
#  'Anniston',
#  'Anniston',
#  'Annona',
#  'Annville',
#  'Annville',
#  'Anoka',
#  'Anoka',
#  'Anselmo',
#  'Ansley',
#  'Anson',
#  'Anson',
#  'Ansonia',
#  'Ansonia',
#  'Ansonville',
#  'Ansted',
#  'Antares',
#  'Antelope',
#  'Antelope',
#  'Antelope',
#  'Antelope',
#  'Antelope Hills',
#  'Anthem',
#  'Anthon',
#  'Anthony',
#  'Anthony',
#  'Anthony',
#  'Anthonyville',
#  'Anthoston',
#  'Antietam',
#  'Antigo',
#  'Antimony',
#  'Antioch',
#  'Antioch',
#  'Antioch',
#  'Antioch',
#  'Antler',
#  'Antlers',
#  'Antoine',
#  'Anton',
#  'Anton Chico',
#  'Antonito',
#  'Antreville',
#  'Antrim',
#  'Antwerp',
#  'Antwerp',
#  'Anvik',
#  'Anza',
#  'Anzac Village',
#  'Apache',
#  'Apache Creek',
#  'Apache Junction',
#  'Apalachicola',
#  'Apalachin',
#  'Apex',
#  'Apison',
#  'Aplin',
#  'Aplington',
#  'Apollo',
#  'Apollo Beach',
#  'Apopka',
#  'Appalachia',
#  'Apple Canyon Lake',
#  'Apple Creek',
#  'Apple Grove',
#  'Apple Mountain Lake',
#  'Apple River',
#  'Apple Valley',
#  'Apple Valley',
#  'Apple Valley',
#  'Apple Valley',
#  'Apple Valley',
#  'Appleby',
#  'Applegate',
#  'Appleton',
#  'Appleton',
#  'Appleton',
#  'Appleton City',
#  'Applewold',
#  'Applewood',
#  'Appling',
#  'Appomattox',
#  'Aptos',
#  'Aptos Hills-Larkin Valley',
#  'Aquadale',
#  'Aquasco',
#  'Aquebogue',
#  'Aquia Harbour',
#  'Aquilla',
#  'Aquilla',
#  'Arab',
#  'Arabi',
#  'Arabi',
#  'Aragon',
#  'Aragon',
#  'Aransas Pass',
#  'Arapaho',
#  'Arapahoe',
#  'Arapahoe',
#  'Arapahoe',
#  'Arapahoe',
#  'Arbela',
#  'Arboles',
#  'Arbon Valley',
#  'Arbovale',
#  'Arbuckle',
#  'Arbury Hills',
#  'Arbutus',
#  'Arbyrd',
#  'Arcade',
#  'Arcade',
#  'Arcadia',
#  'Arcadia',
#  'Arcadia',
#  'Arcadia',
#  'Arcadia',
#  'Arcadia',
#  'Arcadia',
#  'Arcadia',
#  'Arcadia',
#  'Arcadia',
#  'Arcadia',
#  'Arcadia',
#  'Arcadia',
#  'Arcadia Lakes',
#  'Arcadia University',
#  'Arcanum',
#  'Arcata',
#  'Archbald',
#  'Archbold',
#  'Archdale',
#  'Archer',
#  'Archer',
#  'Archer',
#  'Archer City',
#  'Archer Lodge',
#  'Archie',
#  'Arco',
#  'Arco',
#  'Arcola',
#  'Arcola',
#  'Arcola',
#  'Arcola',
#  'Arcola',
#  'Arctic Village',
#  'Arden',
#  'Arden Hills',
#  'Arden on the Severn',
#  'Arden-Arcade',
#  'Ardencroft',
#  'Ardentown',
#  'Ardmore',
#  'Ardmore',
#  'Ardmore',
#  'Ardmore',
#  'Ardmore',
#  'Ardoch',
#  'Ardsley',
#  'Aredale',
#  'Arena',
#  'Arenas Valley',
#  'Arendtsville',
#  'Arenzville',
#  'Argenta',
#  'Argenta',
#  'Argentine',
#  'Argo',
#  'Argo',
#  'Argonia',
#  'Argonne',
#  'Argos',
#  'Argusville',
#  'Argyle',
#  'Argyle',
#  'Argyle',
#  'Argyle',
#  'Argyle',
#  'Argyle',
#  'Argyle',
#  'Argyle',
#  'Arial',
#  'Arimo',
#  'Arion',
#  'Aripeka',
#  'Arispe',
#  'Aristes',
#  'Aristocrat Ranchettes',
#  'Ariton',
#  'Arivaca',
#  'Arivaca Junction',
#  'Arizona City',
#  'Arizona Village',
#  'Arjay',
#  'Arkabutla',
#  'Arkadelphia',
#  'Arkansas City',
#  'Arkansas City',
#  'Arkansaw',
#  'Arkdale',
#  'Arkoe',
#  'Arkoma',
#  'Arkport',
#  'Arkwright',
#  'Arlee',
#  'Arley',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington Heights',
#  'Arlington Heights',
#  'Arlington Heights',
#  'Arlington Heights',
#  'Arma',
#  'Armada',
#  'Armagh',
#  'Armington',
#  'Armona',
#  'Armonk',
#  'Armorel',
#  'Armour',
#  'Armstrong',
#  'Armstrong',
#  'Armstrong',
#  'Arnaudville',
#  'Arnegard',
#  'Arnett',
#  'Arnold',
#  'Arnold',
#  'Arnold',
#  'Arnold',
#  'Arnold',
#  'Arnold City',
#  'Arnold Line',
#  'Arnolds Park',
#  'Arnoldsville',
#  'Arnot',
#  'Aroma Park',
#  'Aromas',
#  'Arona',
#  'Arp',
#  'Arpelar',
#  'Arpin',
#  'Arrey',
#  'Arriba',
#  'Arrington',
#  'Arrow Point',
#  'Arrow Rock',
#  'Arrowhead Beach',
#  'Arrowhead Lake',
#  'Arrowhead Springs',
#  'Arrowsmith',
#  'Arroyo Colorado Estates',
#  'Arroyo Gardens',
#  'Arroyo Grande',
#  'Arroyo Hondo',
#  'Arroyo Hondo',
#  'Arroyo Seco',
#  'Artas',
#  'Artemus',
#  ...]

# %%
missing_city = [set(geo_list) - set(city_list)]
missing_city
# Out:
# [{'Camp Casey',
#   'Camp Humphreys',
#   'Clackamas',
#   'Cp Ripley',
#   'Dal Molin',
#   'Del Valle Afrc',
#   'East Camp Graffen',
#   'Eglin Afb Destin',
#   'Fort Benning',
#   'Fort Campbell',
#   'Fort Gordon',
#   'Fort Jackson',
#   'Fort Leavenworth',
#   'Fort Polk',
#   'Fort Sam Houston',
#   'Fort Shafter',
#   'Fort Sill',
#   'Fort Snelling',
#   'Fort Wainwright',
#   'Gunpowder',
#   'Honolulu',
#   'Humphries En Ctr',
#   'Hunter Aaf',
#   'Indianapolis',
#   'Invergrove',
#   'Islamabad',
#   'Jb Elmendorf-Rich',
#   'Jb Lewis-Mcchord',
#   'Jb Mcguire-Dix',
#   'Jblm Lewis',
#   'Jbph-H Hickam Fld',
#   'Macdill Afb',
#   'Mainz Kastel',
#   'Managua',
#   'Mcleansville',
#   'Molesworth',
#   'Natick',
#   'Panzer Kaserne Rp',
#   'Peterson Sfb',
#   'Rc Havelock',
#   'Red House',
#   'Rock Island Ars',
#   'S Camp Vilseck',
#   'Saint Louis',
#   'Schofield Brks',
#   'Sembach',
#   'Seoul',
#   'Shaw Afb',
#   'Smith Barracks',
#   'St Augustine',
#   'St Louis',
#   'Vicenza',
#   'Wheeler Aaf',
#   'Wiesbaden Clay Ks'}]
